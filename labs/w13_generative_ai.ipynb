# %% [markdown]
# # Week 13 — Generative AI (Diffusion / Multimodal) + RLHF
#
# **Objective / วัตถุประสงค์:** ทดลอง generative models และเข้าใจแนวคิด RLHF
#
# **สิ่งที่ต้องทำ (Tasks):**
# - รัน text-to-image ด้วย diffusion pipeline
# - ทดลอง multimodal model (image+text)
# - อภิปรายหลักการ RLHF: reward model + policy optimization

# %% [markdown]
# ## 1) Setup

# %%
# !pip install diffusers transformers accelerate
# from diffusers import StableDiffusionPipeline

# %% [markdown]
# ## 2) Your work / TODO

# %%
# TODO: generate an image from a text prompt
pass
