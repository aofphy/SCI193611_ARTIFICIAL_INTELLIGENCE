# %% [markdown]
# # Week 5 — Logic & Automated Planning
#
# **Objective / วัตถุประสงค์:** แทนความรู้ด้วยตรรกะ (propositional/first-order) และแก้ปัญหาด้วยการวางแผนอัตโนมัติ
#
# **สิ่งที่ต้องทำ (Tasks):**
# - เขียน knowledge base และทำ inference (เช่น DPLL/forward chaining)
# - นิยามปัญหาวางแผนแบบ STRIPS (states, actions, goal)
# - เรียกตัวแก้ปัญหา (เช่น pyperplan) และวิเคราะห์แผนที่ได้

# %% [markdown]
# ## 1) Setup

# %%
# !pip install pyperplan sympy
import sympy

# %% [markdown]
# ## 2) Your work / TODO

# %%
# TODO: define your planning domain/problem and solve it
pass
