# %% [markdown]
# # Week 12 — RAG & LLM Agents
#
# **Objective / วัตถุประสงค์:** สร้าง pipeline แบบ Retrieval-Augmented Generation และ agent ที่ใช้ tools/function calling
#
# **สิ่งที่ต้องทำ (Tasks):**
# - ฝัง (embed) เอกสารและเก็บใน vector store (FAISS/Chroma)
# - retrieve context แล้วส่งให้ LLM ตอบคำถาม (RAG)
# - เพิ่ม tool/function calling ให้ agent เรียกเครื่องมือภายนอก

# %% [markdown]
# ## 1) Setup

# %%
# !pip install langchain faiss-cpu sentence-transformers
# import langchain ...

# %% [markdown]
# ## 2) Your work / TODO

# %%
# TODO: build a minimal RAG chain, then add a tool-using agent
pass
