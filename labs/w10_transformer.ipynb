# %% [markdown]
# # Week 10 — The Transformer Architecture
#
# **Objective / วัตถุประสงค์:** เข้าใจกลไก self-attention และประกอบ Transformer block อย่างง่าย
#
# **สิ่งที่ต้องทำ (Tasks):**
# - implement scaled dot-product attention ด้วย NumPy/PyTorch
# - ต่อเป็น multi-head attention + feed-forward block
# - ทดสอบกับ sequence ตัวอย่างและตรวจ shape ของผลลัพธ์

# %% [markdown]
# ## 1) Setup

# %%
# !pip install torch
import torch, torch.nn as nn

# %% [markdown]
# ## 2) Your work / TODO

# %%
# TODO: implement scaled_dot_product_attention(q,k,v)
pass
