# %% [markdown]
# # Week 11 — LLMs: Fine-tuning & Prompting
#
# **Objective / วัตถุประสงค์:** ใช้โมเดลภาษาขนาดใหญ่ผ่าน Hugging Face: prompting และ fine-tuning เบื้องต้น
#
# **สิ่งที่ต้องทำ (Tasks):**
# - โหลด pretrained model/tokenizer และทำ inference
# - ทดลอง prompting techniques (zero/few-shot)
# - ทำ fine-tuning ขนาดเล็ก (เช่น LoRA) บนชุดข้อมูลตัวอย่าง

# %% [markdown]
# ## 1) Setup

# %%
# !pip install transformers datasets peft accelerate
from transformers import AutoTokenizer, AutoModelForCausalLM

# %% [markdown]
# ## 2) Your work / TODO

# %%
# TODO: load a small model and try a few-shot prompt
pass
